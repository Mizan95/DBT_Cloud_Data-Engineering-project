# %%
# %sql
CREATE TABLE IF NOT EXISTS databricksv2.bronze.address
USING parquet
LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/Address/Address.parquet';

# %%
# %sql
-- Create explicit, queryable pointers to your ADLS storage accounts
CREATE TABLE IF NOT EXISTS databricksv2.bronze.customer
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/Customer/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.customeraddress
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/CustomerAddress/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.product
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/Product/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.productcategory
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/ProductCategory/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.productdescription
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/ProductDescription/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.productmodel
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/ProductModel/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.productmodelproductdescription
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/ProductModelProductDescription/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.salesorderdetail
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/SalesOrderDetail/';

CREATE TABLE IF NOT EXISTS databricksv2.bronze.salesorderheader
USING parquet LOCATION 'abfss://bronze@intechstorage.dfs.core.windows.net/SalesLT/SalesOrderHeader/';
